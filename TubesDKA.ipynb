# %%
import networkx as nx
import matplotlib.pyplot as plt

# Inisialisasi graf untuk peta desa
G = nx.Graph()

# Node TPS (3 Titik awal/akhir armada)
G.add_node("TPS_1", tipe="TPS", akses="Semua", kapasitas_sisa=450, terisi=0, pos=(10, 50))
G.add_node("TPS_2", tipe="TPS", akses="Semua", kapasitas_sisa=500, terisi=0, pos=(50, 50))
G.add_node("TPS_3", tipe="TPS", akses="Semua", kapasitas_sisa=400, terisi=0, pos=(30, 5))

# Node Rumah Utama yang bisa diakses truk dan gerobak (60 titik)
# Poros tengah
G.add_node("RU_1", tipe="Rumah", akses="Semua", sampah=2, pos=(10, 10))
G.add_node("RU_2", tipe="Rumah", akses="Semua", sampah=5, pos=(12, 12))
G.add_node("RU_3", tipe="Rumah", akses="Semua", sampah=1, pos=(14, 14))
G.add_node("RU_4", tipe="Rumah", akses="Semua", sampah=7, pos=(16, 15))
G.add_node("RU_5", tipe="Rumah", akses="Semua", sampah=0, pos=(18, 15))
G.add_node("RU_6", tipe="Rumah", akses="Semua", sampah=3, pos=(20, 16))
G.add_node("RU_7", tipe="Rumah", akses="Semua", sampah=6, pos=(22, 18))
G.add_node("RU_8", tipe="Rumah", akses="Semua", sampah=4, pos=(24, 20))
G.add_node("RU_9", tipe="Rumah", akses="Semua", sampah=2, pos=(25, 22))
G.add_node("RU_10", tipe="Rumah", akses="Semua", sampah=5, pos=(26, 25))
G.add_node("RU_11", tipe="Rumah", akses="Semua", sampah=3, pos=(27, 28))
G.add_node("RU_12", tipe="Rumah", akses="Semua", sampah=1, pos=(27, 31))
G.add_node("RU_13", tipe="Rumah", akses="Semua", sampah=6, pos=(28, 34))
G.add_node("RU_14", tipe="Rumah", akses="Semua", sampah=0, pos=(29, 37))
G.add_node("RU_15", tipe="Rumah", akses="Semua", sampah=4, pos=(30, 40))
G.add_node("RU_16", tipe="Rumah", akses="Semua", sampah=7, pos=(32, 43))
G.add_node("RU_17", tipe="Rumah", akses="Semua", sampah=2, pos=(34, 45))
G.add_node("RU_18", tipe="Rumah", akses="Semua", sampah=5, pos=(37, 47))
G.add_node("RU_19", tipe="Rumah", akses="Semua", sampah=1, pos=(40, 48))
G.add_node("RU_20", tipe="Rumah", akses="Semua", sampah=3, pos=(43, 49))

# Lingkar selatan
G.add_node("RU_21", tipe="Rumah", akses="Semua", sampah=4, pos=(17, 13))
G.add_node("RU_22", tipe="Rumah", akses="Semua", sampah=6, pos=(19, 11))
G.add_node("RU_23", tipe="Rumah", akses="Semua", sampah=2, pos=(22, 9))
G.add_node("RU_24", tipe="Rumah", akses="Semua", sampah=0, pos=(25, 8))
G.add_node("RU_25", tipe="Rumah", akses="Semua", sampah=5, pos=(28, 8))
G.add_node("RU_26", tipe="Rumah", akses="Semua", sampah=7, pos=(31, 8))
G.add_node("RU_27", tipe="Rumah", akses="Semua", sampah=3, pos=(34, 9))
G.add_node("RU_28", tipe="Rumah", akses="Semua", sampah=1, pos=(37, 11))
G.add_node("RU_29", tipe="Rumah", akses="Semua", sampah=4, pos=(40, 13))
G.add_node("RU_30", tipe="Rumah", akses="Semua", sampah=6, pos=(42, 16))
G.add_node("RU_31", tipe="Rumah", akses="Semua", sampah=2, pos=(44, 19))
G.add_node("RU_32", tipe="Rumah", akses="Semua", sampah=5, pos=(45, 22))
G.add_node("RU_33", tipe="Rumah", akses="Semua", sampah=1, pos=(45, 25))
G.add_node("RU_34", tipe="Rumah", akses="Semua", sampah=7, pos=(44, 28))
G.add_node("RU_35", tipe="Rumah", akses="Semua", sampah=0, pos=(42, 31))
G.add_node("RU_36", tipe="Rumah", akses="Semua", sampah=3, pos=(39, 33))
G.add_node("RU_37", tipe="Rumah", akses="Semua", sampah=6, pos=(36, 35))
G.add_node("RU_38", tipe="Rumah", akses="Semua", sampah=4, pos=(33, 36))
G.add_node("RU_39", tipe="Rumah", akses="Semua", sampah=2, pos=(30, 37))
G.add_node("RU_40", tipe="Rumah", akses="Semua", sampah=5, pos=(31, 40))

# Lingkar utara barat
G.add_node("RU_41", tipe="Rumah", akses="Semua", sampah=3, pos=(24, 28))
G.add_node("RU_42", tipe="Rumah", akses="Semua", sampah=6, pos=(21, 29))
G.add_node("RU_43", tipe="Rumah", akses="Semua", sampah=1, pos=(18, 30))
G.add_node("RU_44", tipe="Rumah", akses="Semua", sampah=7, pos=(15, 31))
G.add_node("RU_45", tipe="Rumah", akses="Semua", sampah=0, pos=(12, 33))
G.add_node("RU_46", tipe="Rumah", akses="Semua", sampah=4, pos=(10, 36))
G.add_node("RU_47", tipe="Rumah", akses="Semua", sampah=2, pos=(9, 39))
G.add_node("RU_48", tipe="Rumah", akses="Semua", sampah=5, pos=(9, 42))
G.add_node("RU_49", tipe="Rumah", akses="Semua", sampah=3, pos=(10, 45))
G.add_node("RU_50", tipe="Rumah", akses="Semua", sampah=6, pos=(12, 48))
G.add_node("RU_51", tipe="Rumah", akses="Semua", sampah=4, pos=(15, 50))
G.add_node("RU_52", tipe="Rumah", akses="Semua", sampah=1, pos=(18, 51))
G.add_node("RU_53", tipe="Rumah", akses="Semua", sampah=7, pos=(22, 52))
G.add_node("RU_54", tipe="Rumah", akses="Semua", sampah=2, pos=(26, 52))
G.add_node("RU_55", tipe="Rumah", akses="Semua", sampah=5, pos=(30, 51))
G.add_node("RU_56", tipe="Rumah", akses="Semua", sampah=0, pos=(34, 51))
G.add_node("RU_57", tipe="Rumah", akses="Semua", sampah=3, pos=(38, 50))
G.add_node("RU_58", tipe="Rumah", akses="Semua", sampah=6, pos=(42, 50))
G.add_node("RU_59", tipe="Rumah", akses="Semua", sampah=2, pos=(46, 50))
G.add_node("RU_60", tipe="Rumah", akses="Semua", sampah=4, pos=(50, 49))

# Node Rumah Gang yang hanya bisa diakses gerobak (40 titik)
# Gang A (Buntu)
G.add_node("RG_1", tipe="Rumah", akses="Gerobak", sampah=4, pos=(17, 17))
G.add_node("RG_2", tipe="Rumah", akses="Gerobak", sampah=1, pos=(19, 18))
G.add_node("RG_3", tipe="Rumah", akses="Gerobak", sampah=6, pos=(21, 19))
G.add_node("RG_4", tipe="Rumah", akses="Gerobak", sampah=3, pos=(23, 19))
G.add_node("RG_5", tipe="Rumah", akses="Gerobak", sampah=0, pos=(25, 18))
G.add_node("RG_6", tipe="Rumah", akses="Gerobak", sampah=5, pos=(27, 17))
G.add_node("RG_7", tipe="Rumah", akses="Gerobak", sampah=7, pos=(29, 16))
G.add_node("RG_8", tipe="Rumah", akses="Gerobak", sampah=2, pos=(31, 15))
G.add_node("RG_9", tipe="Rumah", akses="Gerobak", sampah=4, pos=(33, 14))
G.add_node("RG_10", tipe="Rumah", akses="Gerobak", sampah=1, pos=(35, 13))

# Gang B (Melingkar)
G.add_node("RG_11", tipe="Rumah", akses="Gerobak", sampah=3, pos=(19, 32))
G.add_node("RG_12", tipe="Rumah", akses="Gerobak", sampah=6, pos=(20, 34))
G.add_node("RG_13", tipe="Rumah", akses="Gerobak", sampah=2, pos=(21, 36))
G.add_node("RG_14", tipe="Rumah", akses="Gerobak", sampah=5, pos=(22, 38))
G.add_node("RG_15", tipe="Rumah", akses="Gerobak", sampah=1, pos=(22, 40))
G.add_node("RG_16", tipe="Rumah", akses="Gerobak", sampah=7, pos=(21, 42))
G.add_node("RG_17", tipe="Rumah", akses="Gerobak", sampah=0, pos=(19, 44))
G.add_node("RG_18", tipe="Rumah", akses="Gerobak", sampah=4, pos=(17, 45))
G.add_node("RG_19", tipe="Rumah", akses="Gerobak", sampah=2, pos=(15, 44))
G.add_node("RG_20", tipe="Rumah", akses="Gerobak", sampah=5, pos=(13, 44))
G.add_node("RG_21", tipe="Rumah", akses="Gerobak", sampah=5, pos=(24, 38))
G.add_node("RG_22", tipe="Rumah", akses="Gerobak", sampah=0, pos=(26, 38))
G.add_node("RG_23", tipe="Rumah", akses="Gerobak", sampah=3, pos=(28, 37))
G.add_node("RG_24", tipe="Rumah", akses="Gerobak", sampah=7, pos=(30, 36))
G.add_node("RG_25", tipe="Rumah", akses="Gerobak", sampah=2, pos=(32, 35))

# Gang C (Tembus Utara)
G.add_node("RG_26", tipe="Rumah", akses="Gerobak", sampah=6, pos=(38, 36))
G.add_node("RG_27", tipe="Rumah", akses="Gerobak", sampah=1, pos=(40, 37))
G.add_node("RG_28", tipe="Rumah", akses="Gerobak", sampah=4, pos=(41, 39))
G.add_node("RG_29", tipe="Rumah", akses="Gerobak", sampah=7, pos=(41, 41))
G.add_node("RG_30", tipe="Rumah", akses="Gerobak", sampah=3, pos=(40, 43))
G.add_node("RG_31", tipe="Rumah", akses="Gerobak", sampah=2, pos=(39, 45))
G.add_node("RG_32", tipe="Rumah", akses="Gerobak", sampah=5, pos=(38, 47))
G.add_node("RG_33", tipe="Rumah", akses="Gerobak", sampah=1, pos=(38, 49))
G.add_node("RG_34", tipe="Rumah", akses="Gerobak", sampah=4, pos=(43, 39))
G.add_node("RG_35", tipe="Rumah", akses="Gerobak", sampah=7, pos=(45, 39))
G.add_node("RG_36", tipe="Rumah", akses="Gerobak", sampah=0, pos=(47, 39))
G.add_node("RG_37", tipe="Rumah", akses="Gerobak", sampah=3, pos=(48, 41))
G.add_node("RG_38", tipe="Rumah", akses="Gerobak", sampah=6, pos=(48, 43))
G.add_node("RG_39", tipe="Rumah", akses="Gerobak", sampah=2, pos=(47, 45))
G.add_node("RG_40", tipe="Rumah", akses="Gerobak", sampah=5, pos=(46, 47))

# Menghubungkan jalan utama ke lokasi TPS
G.add_edge("TPS_1", "RU_51", weight=2, akses="Semua")
G.add_edge("TPS_2", "RU_60", weight=2, akses="Semua")
G.add_edge("TPS_3", "RU_25", weight=4, akses="Semua")
G.add_edge("TPS_3", "RU_26", weight=3, akses="Semua")

# Hubungan jalur jalan utama (Poros tengah)
G.add_edge("RU_1", "RU_2", weight=2, akses="Semua")
G.add_edge("RU_2", "RU_3", weight=2, akses="Semua")
G.add_edge("RU_3", "RU_4", weight=2, akses="Semua")
G.add_edge("RU_4", "RU_5", weight=2, akses="Semua")
G.add_edge("RU_5", "RU_6", weight=2, akses="Semua")
G.add_edge("RU_6", "RU_7", weight=2, akses="Semua")
G.add_edge("RU_7", "RU_8", weight=2, akses="Semua")
G.add_edge("RU_8", "RU_9", weight=2, akses="Semua")
G.add_edge("RU_9", "RU_10", weight=2, akses="Semua")
G.add_edge("RU_10", "RU_11", weight=2, akses="Semua")
G.add_edge("RU_11", "RU_12", weight=2, akses="Semua")
G.add_edge("RU_12", "RU_13", weight=2, akses="Semua")
G.add_edge("RU_13", "RU_14", weight=2, akses="Semua")
G.add_edge("RU_14", "RU_15", weight=2, akses="Semua")
G.add_edge("RU_15", "RU_16", weight=2, akses="Semua")
G.add_edge("RU_16", "RU_17", weight=2, akses="Semua")
G.add_edge("RU_17", "RU_18", weight=2, akses="Semua")
G.add_edge("RU_18", "RU_19", weight=2, akses="Semua")
G.add_edge("RU_19", "RU_20", weight=2, akses="Semua")

# Hubungan jalur jalan utama (Lingkar selatan)
G.add_edge("RU_4", "RU_21", weight=2, akses="Semua")
G.add_edge("RU_21", "RU_22", weight=2, akses="Semua")
G.add_edge("RU_22", "RU_23", weight=3, akses="Semua")
G.add_edge("RU_23", "RU_24", weight=2, akses="Semua")
G.add_edge("RU_24", "RU_25", weight=2, akses="Semua")
G.add_edge("RU_25", "RU_26", weight=2, akses="Semua")
G.add_edge("RU_26", "RU_27", weight=2, akses="Semua")
G.add_edge("RU_27", "RU_28", weight=2, akses="Semua")
G.add_edge("RU_28", "RU_29", weight=2, akses="Semua")
G.add_edge("RU_29", "RU_30", weight=2, akses="Semua")
G.add_edge("RU_30", "RU_31", weight=2, akses="Semua")
G.add_edge("RU_31", "RU_32", weight=2, akses="Semua")
G.add_edge("RU_32", "RU_33", weight=2, akses="Semua")
G.add_edge("RU_33", "RU_34", weight=2, akses="Semua")
G.add_edge("RU_34", "RU_35", weight=2, akses="Semua")
G.add_edge("RU_35", "RU_36", weight=2, akses="Semua")
G.add_edge("RU_36", "RU_37", weight=2, akses="Semua")
G.add_edge("RU_37", "RU_38", weight=2, akses="Semua")
G.add_edge("RU_38", "RU_39", weight=2, akses="Semua")
G.add_edge("RU_39", "RU_14", weight=3, akses="Semua")
G.add_edge("RU_39", "RU_40", weight=2, akses="Semua")

# Hubungan jalur jalan utama (Lingkar utara barat)
G.add_edge("RU_11", "RU_41", weight=2, akses="Semua")
G.add_edge("RU_41", "RU_42", weight=2, akses="Semua")
G.add_edge("RU_42", "RU_43", weight=2, akses="Semua")
G.add_edge("RU_43", "RU_44", weight=2, akses="Semua")
G.add_edge("RU_44", "RU_45", weight=2, akses="Semua")
G.add_edge("RU_45", "RU_46", weight=2, akses="Semua")
G.add_edge("RU_46", "RU_47", weight=2, akses="Semua")
G.add_edge("RU_47", "RU_48", weight=2, akses="Semua")
G.add_edge("RU_48", "RU_49", weight=2, akses="Semua")
G.add_edge("RU_49", "RU_50", weight=2, akses="Semua")
G.add_edge("RU_50", "RU_51", weight=2, akses="Semua")
G.add_edge("RU_51", "RU_52", weight=2, akses="Semua")
G.add_edge("RU_52", "RU_53", weight=2, akses="Semua")
G.add_edge("RU_53", "RU_54", weight=2, akses="Semua")
G.add_edge("RU_54", "RU_55", weight=2, akses="Semua")
G.add_edge("RU_55", "RU_56", weight=2, akses="Semua")
G.add_edge("RU_56", "RU_57", weight=2, akses="Semua")
G.add_edge("RU_57", "RU_58", weight=2, akses="Semua")
G.add_edge("RU_58", "RU_59", weight=2, akses="Semua")
G.add_edge("RU_59", "RU_60", weight=2, akses="Semua")

# Hubungan jalan di dalam gang buntu dan jalan tembus (Khusus Gerobak)
# Gang A
G.add_edge("RU_8", "RG_1", weight=1, akses="Gerobak")
G.add_edge("RG_1", "RG_2", weight=1, akses="Gerobak")
G.add_edge("RG_2", "RG_3", weight=1, akses="Gerobak")
G.add_edge("RG_3", "RG_4", weight=1, akses="Gerobak")
G.add_edge("RG_4", "RG_5", weight=1, akses="Gerobak")
G.add_edge("RG_5", "RG_6", weight=1, akses="Gerobak")
G.add_edge("RG_6", "RG_7", weight=1, akses="Gerobak")
G.add_edge("RG_7", "RG_8", weight=1, akses="Gerobak")
G.add_edge("RG_8", "RG_9", weight=1, akses="Gerobak")
G.add_edge("RG_9", "RG_10", weight=1, akses="Gerobak")

# Gang B
G.add_edge("RU_43", "RG_11", weight=1, akses="Gerobak")
G.add_edge("RG_11", "RG_12", weight=1, akses="Gerobak")
G.add_edge("RG_12", "RG_13", weight=1, akses="Gerobak")
G.add_edge("RG_13", "RG_14", weight=1, akses="Gerobak")
G.add_edge("RG_14", "RG_15", weight=1, akses="Gerobak")
G.add_edge("RG_15", "RG_16", weight=1, akses="Gerobak")
G.add_edge("RG_16", "RG_17", weight=1, akses="Gerobak")
G.add_edge("RG_17", "RG_18", weight=1, akses="Gerobak")
G.add_edge("RG_18", "RG_19", weight=1, akses="Gerobak")
G.add_edge("RG_19", "RG_20", weight=1, akses="Gerobak")
G.add_edge("RG_20", "RU_48", weight=1, akses="Gerobak")
G.add_edge("RG_14", "RG_21", weight=1, akses="Gerobak")
G.add_edge("RG_21", "RG_22", weight=1, akses="Gerobak")
G.add_edge("RG_22", "RG_23", weight=1, akses="Gerobak")
G.add_edge("RG_23", "RG_24", weight=1, akses="Gerobak")
G.add_edge("RG_24", "RG_25", weight=1, akses="Gerobak")

# Gang C
G.add_edge("RU_37", "RG_26", weight=1, akses="Gerobak")
G.add_edge("RG_26", "RG_27", weight=1, akses="Gerobak")
G.add_edge("RG_27", "RG_28", weight=1, akses="Gerobak")
G.add_edge("RG_28", "RG_29", weight=1, akses="Gerobak")
G.add_edge("RG_29", "RG_30", weight=1, akses="Gerobak")
G.add_edge("RG_30", "RG_31", weight=1, akses="Gerobak")
G.add_edge("RG_31", "RG_32", weight=1, akses="Gerobak")
G.add_edge("RG_32", "RG_33", weight=1, akses="Gerobak")
G.add_edge("RG_33", "RU_55", weight=2, akses="Gerobak")
G.add_edge("RG_28", "RG_34", weight=1, akses="Gerobak")
G.add_edge("RG_34", "RG_35", weight=1, akses="Gerobak")
G.add_edge("RG_35", "RG_36", weight=1, akses="Gerobak")
G.add_edge("RG_36", "RG_37", weight=1, akses="Gerobak")
G.add_edge("RG_37", "RG_38", weight=1, akses="Gerobak")
G.add_edge("RG_38", "RG_39", weight=1, akses="Gerobak")
G.add_edge("RG_39", "RG_40", weight=1, akses="Gerobak")
G.add_edge("RG_40", "RU_59", weight=2, akses="Gerobak")

# Pengelompokan tipe node rumah dan TPS
HOUSE_NODES = [n for n, attr in G.nodes(data=True) if attr['tipe'] == "Rumah"]
TPS_NODES = [n for n, attr in G.nodes(data=True) if attr['tipe'] == "TPS"]

# Perhitungan matriks jarak antar node memakai algoritma Dijkstra
distance_matrix = dict(nx.all_pairs_dijkstra_path_length(G, weight='weight'))

# Plotting peta desa menggunakan matplotlib
posisi = nx.get_node_attributes(G, 'pos')
plt.figure(figsize=(16, 12))

node_tps = TPS_NODES
node_ru = [n for n, attr in G.nodes(data=True) if attr['tipe'] == "Rumah" and attr['akses'] == "Semua"]
node_rg = [n for n, attr in G.nodes(data=True) if attr['tipe'] == "Rumah" and attr['akses'] == "Gerobak"]

edge_semua = [(u, v) for u, v, attr in G.edges(data=True) if attr['akses'] == "Semua"]
edge_gerobak = [(u, v) for u, v, attr in G.edges(data=True) if attr['akses'] == "Gerobak"]
 
nx.draw_networkx_edges(G, posisi, edgelist=edge_semua, width=4.0, edge_color='#9E9E9E', alpha=0.8)
nx.draw_networkx_edges(G, posisi, edgelist=edge_gerobak, width=2.0, edge_color='#D84315', style='dashed')

nx.draw_networkx_nodes(G, posisi, nodelist=node_tps, node_color='#D32F2F', node_shape='s', node_size=1200, label="TPS (Depot Awal)")
nx.draw_networkx_nodes(G, posisi, nodelist=node_ru, node_color='#42A5F5', node_shape='o', node_size=300, label="Jalan Utama (Truk & Gerobak)")
nx.draw_networkx_nodes(G, posisi, nodelist=node_rg, node_color='#FFB300', node_shape='d', node_size=200, label="Gang (Khusus Gerobak)")

labels = {n: n.split('_')[1] for n in G.nodes()}
nx.draw_networkx_labels(G, posisi, labels, font_size=8, font_color='black', font_weight='bold')

plt.title("Peta Logistik Desa Statis (100 Rumah & 3 TPS Depot)\nGaris Tebal: Rute Truk/Gerobak | Garis Putus-Putus: Jalur Khusus Gerobak", fontsize=14, fontweight='bold')
plt.legend(loc='lower left', fontsize=12)
plt.axis('off')
plt.tight_layout()
plt.show()

print("-> Graf dan Matriks Jarak antar-node berhasil dimodelkan dengan Algoritma Dijkstra.")
print(f"-> Terdaftar: {len(HOUSE_NODES)} Rumah Penduduk dan {len(TPS_NODES)} Lokasi TPS Strategis.")
# Out:
# -> Graf dan Matriks Jarak antar-node berhasil dimodelkan dengan Algoritma Dijkstra.
# -> Terdaftar: 100 Rumah Penduduk dan 3 Lokasi TPS Strategis.

# %%
import random

# Inisialisasi variabel pelacak sampah desa
house_waste = {}        
total_initial_waste = 0 
waste_events = {}       

# Fungsi membuat jadwal distribusi pembuangan sampah warga
def generate_jadwal_sampah(graf):
    global total_initial_waste, house_waste, waste_events
    total_sampah = 0
    jumlah_rumah = 0
    
    house_waste = {}
    waste_events = {}

    # Opsi berat sampah harian dan bobot peluang kemunculannya
    berat_opsi = [0, 1, 2, 3, 4, 5, 6, 7]
    berat_bobot = [0.05, 0.30, 0.35, 0.15, 0.08, 0.04, 0.02, 0.01] 
    
    # Opsi frekuensi pembuangan dalam sehari
    freq_opsi = [1, 2, 3]
    freq_bobot = [0.60, 0.35, 0.05] 

    for node, data in graf.nodes(data=True):
        if data.get('tipe') == 'Rumah':
            house_waste[node] = 0 
            
            # Memilih total berat sampah harian rumah berdasarkan bobot
            total_harian = random.choices(berat_opsi, weights=berat_bobot, k=1)[0]
            
            if total_harian > 0:
                # Memilih frekuensi buang sampah dan disesuaikan dengan total berat
                frekuensi = random.choices(freq_opsi, weights=freq_bobot, k=1)[0]
                frekuensi = min(frekuensi, total_harian)
                
                # Memecah akumulasi sampah harian menjadi beberapa kantong
                potongan_sampah = []
                sisa = total_harian
                for i in range(frekuensi - 1):
                    buang = random.randint(1, sisa - (frekuensi - 1 - i))
                    potongan_sampah.append(buang)
                    sisa -= buang
                potongan_sampah.append(sisa)
                
                # Penjadwalan waktu pembuangan ke dalam timeline menit
                for muatan in potongan_sampah:
                    # Probabilitas 75% di pagi hari (06:00 - 09:00) dan 25% di siang/sore (09:01 - 16:00)
                    if random.random() <= 0.75:
                        waktu_buang = random.randint(360, 540)
                    else:
                        waktu_buang = random.randint(541, 960)
                        
                    if waktu_buang not in waste_events:
                        waste_events[waktu_buang] = []
                    waste_events[waktu_buang].append((node, muatan))

            total_sampah += total_harian
            jumlah_rumah += 1
            graf.nodes[node]['sampah_harian_total'] = total_harian

    total_initial_waste = total_sampah
    return jumlah_rumah, total_sampah

# Eksekusi fungsi penjadwalan
rumah_diupdate, total_sampah_desa = generate_jadwal_sampah(G)

print("-> Status awal distribusi sampah dinamis berhasil dibuat.")
print(f"-> Jumlah rumah terdaftar: {rumah_diupdate} node.")
print(f"-> Total tumpukan sampah harian: {total_sampah_desa} kg.")
print(f"-> Jumlah log kejadian warga membuang sampah: {sum(len(v) for v in waste_events.values())} data.\n")

print("Sampel urutan waktu pembuangan awal:")
jadwal_terurut = sorted(waste_events.keys())
tampil_max = min(5, len(jadwal_terurut))

for i in range(tampil_max):
    menit = jadwal_terurut[i]
    jam_format = f"{menit // 60:02d}:{menit % 60:02d}"
    kejadian = waste_events[menit]
    for aksi in kejadian:
         print(f" - Jam {jam_format} | {aksi[0]} mengeluarkan sampah seberat {aksi[1]} kg.")
# Out:
# -> Status awal distribusi sampah dinamis berhasil dibuat.
# -> Jumlah rumah terdaftar: 100 node.
# -> Total tumpukan sampah harian: 236 kg.
# -> Jumlah log kejadian warga membuang sampah: 118 data.
#
# Sampel urutan waktu pembuangan awal:
#  - Jam 06:03 | RG_35 mengeluarkan sampah seberat 1 kg.
#  - Jam 06:05 | RG_29 mengeluarkan sampah seberat 1 kg.
#  - Jam 06:08 | RU_35 mengeluarkan sampah seberat 1 kg.
#  - Jam 06:08 | RG_32 mengeluarkan sampah seberat 1 kg.
#  - Jam 06:10 | RU_40 mengeluarkan sampah seberat 1 kg.
#  - Jam 06:17 | RG_11 mengeluarkan sampah seberat 5 kg.

# %%
class Kendaraan:
    def __init__(self, id_kendaraan, tipe, kapasitas_maks, waktu_mulai, waktu_selesai, posisi_awal):
        self.id = id_kendaraan
        self.tipe = tipe 
        self.kapasitas_maks = kapasitas_maks
        self.muatan = 0
        self.waktu_mulai = waktu_mulai
        self.waktu_selesai = waktu_selesai
        
        # Waktu operasional berjalan yang berubah dinamis saat simulasi
        self.waktu_tersedia = waktu_mulai 
        self.posisi = posisi_awal
        self.total_jarak = 0
        self.total_waktu_kerja = 0
        
        # Variabel untuk pencatatan rute dan ekspor ke dataframe pandas
        self.rumah_dikunjungi = 0
        self.kali_buang_tps = 0
        self.kali_transfer = 0
        self.rute_nodes = [posisi_awal] 
        self.log_terstruktur = []       

    def catat_log_detail(self, menit, aksi, lokasi, muatan, jarak, pesan):
        jam = menit // 60
        menit_sisa = menit % 60
        
        # Format log dictionary untuk konversi ke file CSV
        self.log_terstruktur.append({
            "Waktu": f"{jam:02d}:{menit_sisa:02d}",
            "ID_Armada": self.id,
            "Tipe": self.tipe,
            "Aksi": aksi,
            "Lokasi": lokasi,
            "Muatan_kg": muatan,
            "Jarak_Tempuh": jarak,
            "Total_Jarak_Sementara": self.total_jarak,
            "Pesan_Log": pesan
        })
        
        if self.rute_nodes[-1] != lokasi:
            self.rute_nodes.append(lokasi)

# Inisialisasi armada truk berdasarkan pembagian giliran kerja (Shift)
armada_truk = [
    Kendaraan("Truk_1", "Truk", 200, 480, 840, "TPS_1"),  # Shift 1 (08:00 - 14:00)
    Kendaraan("Truk_2", "Truk", 200, 600, 960, "TPS_2"),  # Shift 2 (10:00 - 16:00)
    Kendaraan("Truk_3", "Truk", 200, 660, 1020, "TPS_3")  # Shift 3 (11:00 - 17:00)
]

# Inisialisasi armada gerobak berdasarkan pembagian giliran kerja (Shift)
armada_gerobak = [
    # Shift Pagi (06:00 - 12:00)
    Kendaraan("Gerobak_1", "Gerobak", 15, 360, 720, "TPS_1"),
    Kendaraan("Gerobak_2", "Gerobak", 15, 360, 720, "TPS_1"),
    Kendaraan("Gerobak_3", "Gerobak", 15, 360, 720, "TPS_2"),
    Kendaraan("Gerobak_4", "Gerobak", 15, 360, 720, "TPS_3"),

    # Shift Siang (09:00 - 15:00)
    Kendaraan("Gerobak_5", "Gerobak", 15, 540, 900, "TPS_2"),
    Kendaraan("Gerobak_6", "Gerobak", 15, 540, 900, "TPS_2"),
    Kendaraan("Gerobak_7", "Gerobak", 15, 540, 900, "TPS_3")
]

semua_armada = armada_gerobak + armada_truk

print("-> Setup objek data armada kendaraan berhasil dikonfigurasi.")
print(f"-> Truk terdaftar    : {len(armada_truk)} unit.")
print(f"-> Gerobak terdaftar : {len(armada_gerobak)} unit.")
# Out:
# -> Setup objek data armada kendaraan berhasil dikonfigurasi.
# -> Truk terdaftar    : 3 unit.
# -> Gerobak terdaftar : 7 unit.

# %%
import math

# Menghitung jarak terpendek antar dua node berdasarkan matriks Dijkstra
def get_jarak(node_a, node_b):
    if node_a == node_b: return 0
    return distance_matrix[node_a][node_b]

# Loop utama simulasi berjalan menit demi menit (06:00 hingga 17:00)
for menit_sekarang in range(360, 1021):
    
    # Update volume sampah di rumah jika ada warga yang membuang sampah di menit ini
    if menit_sekarang in waste_events:
        for node, muatan in waste_events[menit_sekarang]:
            house_waste[node] += muatan

    # Filter kendaraan yang masuk jadwal shift dan sedang posisi idle
    armada_aktif = [k for k in semua_armada 
                    if k.waktu_mulai <= menit_sekarang < k.waktu_selesai 
                    and k.waktu_tersedia <= menit_sekarang]
    
    for k in armada_aktif:
        tujuan_akhir = None
        is_pulang_ke_tps = False
        is_transfer_truk = False
        truk_target = None
        
        # 1. CEK STATUS: Apakah penuh atau mau habis waktu shift?
        if k.muatan >= k.kapasitas_maks or (k.waktu_selesai - menit_sekarang < 60 and k.muatan > 0):
            # Target default adalah TPS terdekat
            tujuan_akhir = min(TPS_NODES, key=lambda x: get_jarak(k.posisi, x))
            jarak_tps = get_jarak(k.posisi, tujuan_akhir)
            is_pulang_ke_tps = True
            
            # Logika khusus Gerobak: Cek apakah ada truk terdekat untuk transfer
            if k.tipe == "Gerobak":
                truk_tersedia = [t for t in armada_truk 
                                 if t.waktu_mulai <= menit_sekarang < t.waktu_selesai 
                                 and t.waktu_tersedia <= menit_sekarang 
                                 and (t.kapasitas_maks - t.muatan) >= k.muatan]
                
                if truk_tersedia:
                    truk_pilihan = min(truk_tersedia, key=lambda t: get_jarak(k.posisi, t.posisi))
                    jarak_truk = get_jarak(k.posisi, truk_pilihan.posisi)
                    
                    if jarak_truk < jarak_tps:
                        tujuan_akhir = truk_pilihan.posisi
                        is_transfer_truk = True
                        truk_target = truk_pilihan
                        is_pulang_ke_tps = False # Batal ke TPS, ganti kejar Truk
        else:
            # Targetnya adalah mencari rumah kotor terdekat
            rumah_kotor = [n for n, w in house_waste.items() if w > 0]
            if k.tipe == "Truk":
                rumah_kotor = [n for n in rumah_kotor if G.nodes[n]['akses'] == "Semua"]
                
            if rumah_kotor:
                tujuan_akhir = min(rumah_kotor, key=lambda x: get_jarak(k.posisi, x))
            else:
                k.waktu_tersedia += 15
                continue # Skip ke kendaraan lain jika tidak ada sampah di seluruh desa

        # Jika entah kenapa posisi sudah di tujuan akhir (misal nge-bug), selesaikan tugasnya
        if k.posisi == tujuan_akhir:
             if is_pulang_ke_tps:
                 G.nodes[k.posisi]['kapasitas_sisa'] -= k.muatan
                 G.nodes[k.posisi]['terisi'] += k.muatan
                 k.catat_log_detail(menit_sekarang, "Buang ke TPS", k.posisi, k.muatan, 0, f"Bongkar muatan di {k.posisi}")
                 k.kali_buang_tps += 1
                 k.muatan = 0
             elif is_transfer_truk:
                 k.kali_transfer += 1
                 sampah_dibawa = k.muatan
                 truk_target.muatan += sampah_dibawa
                 truk_target.waktu_tersedia = menit_sekarang + (sampah_dibawa * 2) # Waktu tunggu loading
                 truk_target.total_waktu_kerja += (sampah_dibawa * 2)
                 
                 k.catat_log_detail(menit_sekarang, "Transfer ke Truk", k.posisi, sampah_dibawa, 0, f"Rendezvous dengan {truk_target.id}")
                 truk_target.catat_log_detail(menit_sekarang, "Terima Transfer", k.posisi, sampah_dibawa, 0, f"Menerima muatan dari {k.id}")
                 k.muatan = 0
             
             k.waktu_tersedia += 5 # Istirahat sejenak setelah tugas selesai
             continue

        # 2. EKSTRAK JALUR LANGKAH DEMI LANGKAH
        jalur_lengkap = nx.dijkstra_path(G, k.posisi, tujuan_akhir, weight='weight')
        
        # 3. BERGERAK HANYA 1 LANGKAH
        node_depan = jalur_lengkap[1] 
        jarak_langkah = G[k.posisi][node_depan]['weight']
        
        if k.tipe == "Gerobak":
            waktu_jalan = jarak_langkah * 3
        else:
            waktu_jalan = math.ceil(jarak_langkah / 5) * 3
            
        waktu_load = 0
        sampah_diambil = 0
        aksi_dilakukan = "Patroli Lewat"
        pesan_log = "Melewati persimpangan"
        
        # 4. CEK KONDISI NODE DEPAN (Intercept Sampah jika ada)
        # Boleh ambil sampah JIKA BUKAN sedang dalam misi pulang/transfer, dan ada sampah di depan
        if not is_pulang_ke_tps and not is_transfer_truk and node_depan in house_waste and house_waste[node_depan] > 0:
            sampah_tersedia = house_waste[node_depan]
            sisa_kapasitas = k.kapasitas_maks - k.muatan
            sampah_diambil = min(sampah_tersedia, sisa_kapasitas)
            
            if k.tipe == "Gerobak":
                waktu_load = sampah_diambil * 2
            else:
                waktu_load = math.ceil(sampah_diambil / 10) * 2
                
            house_waste[node_depan] -= sampah_diambil
            k.muatan += sampah_diambil
            k.rumah_dikunjungi += 1
            
            aksi_dilakukan = "Ambil Sampah"
            pesan_log = f"Intercept sampah! Sisa kapasitas: {k.kapasitas_maks - k.muatan}kg"
            
        waktu_total = waktu_jalan + waktu_load
        
        # 5. UPDATE POSISI DAN LOG
        if menit_sekarang + waktu_total <= k.waktu_selesai:
            k.waktu_tersedia = menit_sekarang + waktu_total
            k.total_jarak += jarak_langkah
            k.total_waktu_kerja += waktu_total
            k.posisi = node_depan 
            
            # Jika langkah ini membuatnya tepat tiba di tujuan akhir (TPS atau Truk)
            if node_depan == tujuan_akhir:
                if is_pulang_ke_tps:
                    G.nodes[node_depan]['kapasitas_sisa'] -= k.muatan
                    G.nodes[node_depan]['terisi'] += k.muatan
                    k.catat_log_detail(menit_sekarang, "Buang ke TPS", node_depan, k.muatan, jarak_langkah, f"Bongkar muatan di {node_depan}")
                    k.kali_buang_tps += 1
                    k.muatan = 0
                elif is_transfer_truk:
                    k.kali_transfer += 1
                    sampah_dibawa = k.muatan
                    truk_target.muatan += sampah_dibawa
                    
                    # Sinkronisasi waktu truk menunggu gerobak bongkar muatan
                    truk_target.waktu_tersedia = menit_sekarang + waktu_jalan + (sampah_dibawa * 2) 
                    truk_target.total_waktu_kerja += (sampah_dibawa * 2)
                    
                    k.catat_log_detail(menit_sekarang, "Transfer ke Truk", node_depan, sampah_dibawa, jarak_langkah, f"Rendezvous sukses dengan {truk_target.id}")
                    truk_target.catat_log_detail(menit_sekarang, "Terima Transfer", node_depan, sampah_dibawa, 0, f"Menerima muatan dari {k.id}")
                    k.muatan = 0
                else:
                     k.catat_log_detail(menit_sekarang, aksi_dilakukan, node_depan, sampah_diambil, jarak_langkah, pesan_log)
            else:
                # Jika belum sampai di tujuan akhir, catat aksinya (entah cuma lewat atau ambil sampah)
                k.catat_log_detail(menit_sekarang, aksi_dilakukan, node_depan, sampah_diambil, jarak_langkah, pesan_log)
                
        else:
            k.waktu_tersedia = k.waktu_selesai 

print("-> Simulasi pergerakan logistik step-by-step selesai dijalankan.")
# Out:
# -> Simulasi pergerakan logistik step-by-step selesai dijalankan.

# %%
import pandas as pd

# Menggabungkan seluruh data log dari setiap objek kendaraan
semua_log = []
for k in semua_armada:
    semua_log.extend(k.log_terstruktur)

# Proses konversi data log menjadi file CSV jika data tersedia
if len(semua_log) > 0:
    df_log = pd.DataFrame(semua_log)
    
    # Mengurutkan baris berdasarkan waktu kejadian agar kronologis
    df_log = df_log.sort_values(by=["Waktu"]) 
    
    nama_file = "Log_Perjalanan_Desa.csv"
    df_log.to_csv(nama_file, index=False)
    
    print(f"[*] Berhasil mengekstrak {len(df_log)} baris aktivitas log.")
    print(f"[*] Data tersimpan dalam file: '{nama_file}' (Siap dibuka di Excel)\n")
else:
    print("[!] Tidak ada log aktivitas yang terekam. Pastikan Cell 4 sudah dijalankan.")

print(">>> LAPORAN KINERJA ARMADA (SUMMARY) <<<")
total_jarak_semua = 0
total_waktu_gerobak = 0
total_waktu_truk = 0

# WADAH BARU UNTUK MENJAWAB POIN C DAN E
total_jarak_gerobak = 0 
total_jarak_truk = 0    

# Loop untuk menampilkan performa pergerakan masing-masing kendaraan
for k in semua_armada:
    print(f"[{k.tipe.upper()}] {k.id} (Shift: {k.waktu_mulai//60:02d}:00 - {k.waktu_selesai//60:02d}:00)")
    print(f"  - Rumah Dikunjungi   : {k.rumah_dikunjungi} rumah")
    
    if k.tipe == "Gerobak":
        print(f"  - Bongkar di TPS     : {k.kali_buang_tps} kali")
        print(f"  - Rendezvous (Truk)  : {k.kali_transfer} kali penitipan")
        total_waktu_gerobak += k.total_waktu_kerja
        total_jarak_gerobak += k.total_jarak  # <--- Menabung jarak gerobak
    else:
        print(f"  - Bongkar di TPS     : {k.kali_buang_tps} kali")
        total_waktu_truk += k.total_waktu_kerja    
        total_jarak_truk += k.total_jarak     # <--- Menabung jarak truk
        
    print(f"  - Total Jarak Tempuh : {k.total_jarak} satuan jarak")
    print(f"  - Durasi Kerja Aktif : {k.total_waktu_kerja} menit\n")
    
    total_jarak_semua += k.total_jarak

print(">>> EVALUASI AKHIR LOGISTIK DESA <<<")
# Menghitung total sisa sampah yang belum sempat terangkut
sisa_di_rumah = sum(house_waste.values())
sampah_di_tps = sum([G.nodes[n]['terisi'] for n in TPS_NODES])

# Pengecekan sisa sampah yang masih tertahan di bak armada saat shift habis
sisa_di_gerobak = sum([k.muatan for k in armada_gerobak])
sisa_di_truk = sum([k.muatan for k in armada_truk])

print(f" -> Total Sampah Awal (Estimasi Harian) : {total_initial_waste} kg")
print(f" -> Total Sampah Berhasil Diolah di TPS : {sampah_di_tps} kg")
print(f" -> Total Jarak Tempuh Seluruh Armada   : {total_jarak_semua} satuan jarak\n")

# ======================================================================
# BLOK KOMPARASI (JAWABAN UNTUK POIN C DAN E)
# ======================================================================
print("[KOMPARASI BEBAN KERJA: GEROBAK VS TRUK]")
print(f" -> Total Jarak Tempuh Gerobak (Seluruh unit) : {total_jarak_gerobak} satuan jarak") # <--- JAWABAN POIN E
print(f" -> Total Jarak Tempuh Truk (Seluruh unit)    : {total_jarak_truk} satuan jarak")    # <--- JAWABAN POIN C
print(f" -> Total Waktu Kerja Gerobak                 : {total_waktu_gerobak} menit")
print(f" -> Total Waktu Kerja Truk                    : {total_waktu_truk} menit")
print(f" -> Sisa Sampah Tertahan di bak Gerobak       : {sisa_di_gerobak} kg")
print(f" -> Sisa Sampah Tertahan di bak Truk          : {sisa_di_truk} kg\n")
# ======================================================================

print("[RINCIAN SISA SAMPAH SAAT OPERASI BERAKHIR (17:00)]")
print(f" 1. Sisa sampah di rumah warga             : {sisa_di_rumah} kg")
print(f" 2. Sampah tertahan di bak armada Gerobak  : {sisa_di_gerobak} kg")
print(f" 3. Sampah tertahan di bak armada Truk     : {sisa_di_truk} kg")

# Evaluasi kesuksesan algoritma
if sisa_di_rumah == 0 and sisa_di_gerobak == 0 and sisa_di_truk == 0:
    print("\n[KESIMPULAN]: Pengangkutan sampah sukses total. Seluruh desa dan armada bersih.")
else:
    total_sisa_tak_terolah = sisa_di_rumah + sisa_di_gerobak + sisa_di_truk
    print(f"\n[KESIMPULAN]: Evaluasi rute diperlukan. Total ada {total_sisa_tak_terolah} kg sampah yang tidak masuk ke TPS hari ini.")
# Out:
# [*] Berhasil mengekstrak 695 baris aktivitas log.
# [*] Data tersimpan dalam file: 'Log_Perjalanan_Desa.csv' (Siap dibuka di Excel)
#
# >>> LAPORAN KINERJA ARMADA (SUMMARY) <<<
# [GEROBAK] Gerobak_1 (Shift: 06:00 - 12:00)
#   - Rumah Dikunjungi   : 11 rumah
#   - Bongkar di TPS     : 2 kali
#   - Rendezvous (Truk)  : 1 kali penitipan
#   - Total Jarak Tempuh : 90 satuan jarak
#   - Durasi Kerja Aktif : 340 menit
#
# [GEROBAK] Gerobak_2 (Shift: 06:00 - 12:00)
#   - Rumah Dikunjungi   : 19 rumah
#   - Bongkar di TPS     : 1 kali
#   - Rendezvous (Truk)  : 1 kali penitipan
#   - Total Jarak Tempuh : 94 satuan jarak
#   - Durasi Kerja Aktif : 342 menit
#
# [GEROBAK] Gerobak_3 (Shift: 06:00 - 12:00)
#   - Rumah Dikunjungi   : 10 rumah
#   - Bongkar di TPS     : 1 kali
#   - Rendezvous (Truk)  : 0 kali penitipan
#   - Total Jarak Tempuh : 89 satuan jarak
#   - Durasi Kerja Aktif : 315 menit
#
# [GEROBAK] Gerobak_4 (Shift: 06:00 - 12:00)
#   - Rumah Dikunjungi   : 7 rumah
# ...

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Membaca koordinat posisi node serta mengelompokkan jenis node
posisi = nx.get_node_attributes(G, 'pos')
node_tps = TPS_NODES
node_ru = [n for n, attr in G.nodes(data=True) if attr['tipe'] == "Rumah" and attr['akses'] == "Semua"]
node_rg = [n for n, attr in G.nodes(data=True) if attr['tipe'] == "Rumah" and attr['akses'] == "Gerobak"]
labels = {n: n.split('_')[1] for n in G.nodes()}

# Plotting grafik visualisasi rute perjalanan armada Truk
plt.figure(figsize=(16, 10))
plt.title("Analisis Spasial: Jejak Rute Perjalanan TRUK (Shift Berjenjang 08:00 - 17:00)", fontsize=15, fontweight='bold')

# Menggambar kerangka node peta dasar desa
nx.draw_networkx_nodes(G, posisi, nodelist=node_tps, node_color='#D32F2F', node_shape='s', node_size=800, label="TPS (Depot/Pangkalan)")
nx.draw_networkx_nodes(G, posisi, nodelist=node_ru, node_color='#E0E0E0', node_size=150)
nx.draw_networkx_nodes(G, posisi, nodelist=node_rg, node_color='#F5F5F5', node_shape='d', node_size=100)
nx.draw_networkx_labels(G, posisi, labels, font_size=7, font_color='#757575')

warna_truk = ['#1565C0', '#2E7D32', '#6A1B9A'] 

# Menggambar garis rute yang dilalui oleh setiap truk selama simulasi
for idx, t in enumerate(armada_truk):
    if len(t.rute_nodes) > 1:
        edges_truk = [(t.rute_nodes[i], t.rute_nodes[i+1]) for i in range(len(t.rute_nodes)-1)]
        nx.draw_networkx_edges(G, posisi, edgelist=edges_truk, edge_color=warna_truk[idx % len(warna_truk)], 
                               width=3.5, alpha=0.8, label=f"{t.id} ({len(t.rute_nodes)} titik dilalui)")

plt.legend(loc='lower left', fontsize=11, framealpha=0.9)
plt.axis('off')
plt.tight_layout()
plt.show()

# Plotting grafik visualisasi rute perjalanan armada Gerobak
plt.figure(figsize=(16, 10))
plt.title("Analisis Spasial: Jejak Rute Perjalanan GEROBAK (Shift Overlapping 06:00 - 15:00)", fontsize=15, fontweight='bold')

# Menggambar kerangka node peta dasar desa (perbaikan parameter node_size)
nx.draw_networkx_nodes(G, posisi, nodelist=node_tps, node_color='#D32F2F', node_shape='s', node_size=800, label="TPS (Depot/Pangkalan)")
nx.draw_networkx_nodes(G, posisi, nodelist=node_ru, node_color='#E0E0E0', node_size=150)
nx.draw_networkx_nodes(G, posisi, nodelist=node_rg, node_color='#E0E0E0', node_shape='d', node_size=100)
nx.draw_networkx_labels(G, posisi, labels, font_size=7, font_color='#757575')

warna_gerobak = ['#D84315', '#EF6C00', '#F9A825', '#9E9D24', '#00838F', '#0277BD', '#4527A0']

# Menggambar rute gerobak dengan format garis putus-putus (dashed)
for idx, g in enumerate(armada_gerobak):
    if len(g.rute_nodes) > 1:
        edges_gerobak = [(g.rute_nodes[i], g.rute_nodes[i+1]) for i in range(len(g.rute_nodes)-1)]
        nx.draw_networkx_edges(G, posisi, edgelist=edges_gerobak, edge_color=warna_gerobak[idx % len(warna_gerobak)], 
                               width=2.0, alpha=0.7, style='dashed', label=f"{g.id} ({len(g.rute_nodes)} titik dilalui)")

plt.legend(loc='lower left', fontsize=10, ncol=2, framealpha=0.9)
plt.axis('off')
plt.tight_layout()
plt.show()

print("-> Visualisasi rute pergerakan seluruh armada berhasil ditampilkan.")
# Out:
# -> Visualisasi rute pergerakan seluruh armada berhasil ditampilkan.
